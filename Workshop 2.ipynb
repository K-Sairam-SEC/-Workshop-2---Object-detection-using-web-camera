# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from IPython.display import clear_output

# Load a more accurate YOLO model
model = YOLO("yolov8m.pt")

# Open webcam
cap = cv2.VideoCapture(0)

# Check if camera opened
if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    while True:
        ret, frame = cap.read()

        if not ret:
            print("Failed to capture frame.")
            break

        # Perform object detection
        results = model(
            frame,
            conf=0.60,       
            verbose=False
        )

        # Draw bounding boxes and labels
        annotated_frame = results[0].plot()

        # Convert BGR to RGB for Matplotlib
        annotated_frame = cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB)

        # Display in Jupyter
        clear_output(wait=True)
        plt.figure(figsize=(10, 8))
        plt.imshow(annotated_frame)
        plt.title("Real-Time Object Detection")
        plt.axis("off")
        plt.show()

# Release webcam
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 24
#      20             print("Failed to capture frame.")
#      21             break
#      22
#      23         # Perform object detection
# ---> 24         results = model(
#      25             frame,
#      26             conf=0.60,
#      27             verbose=False
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\engine\model.py:166, in Model.__call__(self, source, stream, **kwargs)
#     138 def __call__(
#     139     self,
#     140     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     141     stream: bool = False,
#     142     **kwargs: Any,
#     143 ) -> Iterator[Results | torch.Tensor] | list[Results] | list[torch.Tensor]:
#     144     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     145
#     146     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    164         ...     print(f"Detected {len(r)} objects in image")
#     165     """
# --> 166     return self.predict(source, stream, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\engine\model.py:560, in Model.predict(self, source, stream, predictor, **kwargs)
#     558 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     559     self.predictor.set_prompts(prompts)
# --> 560 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\engine\predictor.py:244, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     242     return self.stream_inference(source, model, *args, **kwargs)
#     243 else:
# --> 244     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\utils\_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\engine\predictor.py:355, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     353 # Inference
#     354 with profilers[1]:
# --> 355     preds = self.inference(im, *args, **kwargs)
#     356     if self.args.embed:
#     357         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\engine\predictor.py:201, in BasePredictor.inference(self, im, *args, **kwargs)
#     190 if self.args.visualize and getattr(self.model, "base_model", True) and not skip:
#     191     return class_activation_map(
#     192         self.model,
#     193         im,
#    (...)    199         **kwargs,
#     200     )
# --> 201 return self.model(im, *args, augment=self.args.augment, embed=self.args.embed, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\nn\autobackend.py:324, in AutoBackend.forward(self, im, augment, embed, **kwargs)
#     321 if self.format == "pt":
#     322     forward_kwargs = {"augment": augment, "embed": embed, **kwargs}
# --> 324 y = self.backend.forward(im, **forward_kwargs)
#     326 if isinstance(y, (list, tuple)):
#     327     if len(self.names) == 999 and (self.task == "segment" or len(y) == 2):  # segments and names not defined
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\nn\backends\pytorch.py:96, in PyTorchBackend.forward(self, im, augment, embed, **kwargs)
#      94 if not self.base_model:  # a foreign nn.Module defines no `augment`/`embed` contract to honor
#      95     return self.model(im, **kwargs)
# ---> 96 return self.model(im, augment=augment, embed=embed, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\nn\tasks.py:161, in BaseModel.forward(self, x, *args, **kwargs)
#     159 if isinstance(x, dict):  # for cases of training and validating while training.
#     160     return self.loss(x, *args, **kwargs)
# --> 161 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\nn\tasks.py:177, in BaseModel.predict(self, x, profile, augment, embed)
#     175 if augment:
#     176     return self._predict_augment(x)
# --> 177 return self._predict_once(x, profile, embed)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\nn\tasks.py:198, in BaseModel._predict_once(self, x, profile, embed)
#     196 if profile:
#     197     self._profile_one_layer(m, x, dt)
# --> 198 x = m(x)  # run
#     199 y.append(x if m.i in self.save else None)  # save output
#     200 if m.i in embed:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\nn\modules\head.py:183, in Detect.forward(self, x)
#     179 def forward(
#     180     self, x: list[torch.Tensor]
#     181 ) -> dict[str, torch.Tensor] | torch.Tensor | tuple[torch.Tensor, dict[str, torch.Tensor]]:
#     182     """Concatenates and returns predicted bounding boxes and class probabilities."""
# --> 183     preds = self.forward_head(x, **self.one2many)
#     184     if getattr(self, "one2one_cv2", None) is not None:
#     185         x_detach = [xi.detach() for xi in x] if self.training else x  # detach keeps one2one out of the backbone
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\nn\modules\head.py:176, in Detect.forward_head(self, x, box_head, cls_head)
#     174 bs = x[0].shape[0]  # batch size
#     175 boxes = torch.cat([box_head[i](x[i]).view(bs, 4 * self.reg_max, -1) for i in range(self.nl)], dim=-1)
# --> 176 scores = torch.cat([cls_head[i](x[i]).view(bs, self.nc, -1) for i in range(self.nl)], dim=-1)
#     177 return {"boxes": boxes, "scores": scores, "feats": x}
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\container.py:259, in Sequential.forward(self, input)
#     255 """
#     256 Runs the forward pass.
#     257 """
#     258 for module in self:
# --> 259     input = module(input)
#     260 return input
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ultralytics\nn\modules\conv.py:89, in Conv.forward_fuse(self, x)
#      80 def forward_fuse(self, x):
#      81     """Apply convolution and activation without batch normalization.
#      82
#      83     Args:
#    (...)     87         (torch.Tensor): Output tensor.
#      88     """
# ---> 89     return self.act(self.conv(x))
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1783, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1781     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1782 else:
# -> 1783     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\module.py:1794, in Module._call_impl(self, *args, **kwargs)
#    1789 # If we don't have any hooks, we want to skip the rest of the logic in
#    1790 # this function, and just call forward.
#    1791 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1792         or _global_backward_pre_hooks or _global_backward_hooks
#    1793         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1794     return forward_call(*args, **kwargs)
#    1796 result = None
#    1797 called_always_called_hooks = set()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\conv.py:565, in Conv2d.forward(self, input)
#     564 def forward(self, input: Tensor) -> Tensor:
# --> 565     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\torch\nn\modules\conv.py:560, in Conv2d._conv_forward(self, input, weight, bias)
#     547 if self.padding_mode != "zeros":
#     548     return F.conv2d(
#     549         F.pad(
#     550             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    557         self.groups,
#     558     )
# --> 560 return F.conv2d(
#     561     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     562 )
#
# KeyboardInterrupt:
